# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('housing.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.describe().transpose()
# Out:
#                       count           mean            std         min  \
# longitude           20640.0    -119.569704       2.003532   -124.3500
# latitude            20640.0      35.631861       2.135952     32.5400
# housing_median_age  20640.0      28.639486      12.585558      1.0000
# total_rooms         20640.0    2635.763081    2181.615252      2.0000
# total_bedrooms      20433.0     537.870553     421.385070      1.0000
# population          20640.0    1425.476744    1132.462122      3.0000
# households          20640.0     499.539680     382.329753      1.0000
# median_income       20640.0       3.870671       1.899822      0.4999
# median_house_value  20640.0  206855.816909  115395.615874  14999.0000
#
#                             25%          50%           75%          max
# longitude             -121.8000    -118.4900    -118.01000    -114.3100
# latitude                33.9300      34.2600      37.71000      41.9500
# ...

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.corr()['total_bedrooms']
# Out:
# C:\Users\LimboLEG\AppData\Local\Temp\ipykernel_12268\556850113.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['total_bedrooms']
# longitude             0.069608
# latitude             -0.066983
# housing_median_age   -0.320451
# total_rooms           0.930380
# total_bedrooms        1.000000
# population            0.877747
# households            0.979728
# median_income        -0.007723
# median_house_value    0.049686
# Name: total_bedrooms, dtype: float64

# %%
df = df.copy()
missing_bedrooms = df['total_bedrooms'].isnull()
# Separating records with and without missing 'total_bedrooms' data
df_with_bedrooms = df[~missing_bedrooms]
df_missing_bedrooms = df[missing_bedrooms]

# %%
from sklearn.linear_model import LinearRegression

# %%
# Using 'total_rooms' and 'households' features to estimate the missing 'total_bedrooms' data
lm = LinearRegression()
lm.fit(df_with_bedrooms[['total_rooms', 'households']], df_with_bedrooms['total_bedrooms'])
# Out:
# LinearRegression()

# %%
pred_br = lm.predict(df_missing_bedrooms[['total_rooms', 'households']])

# %%
df.loc[missing_bedrooms, 'total_bedrooms'] = pred_br

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Creating new features in order to provide more insightful representation of the data
df["rooms_per_household"] = df["total_rooms"]/df["households"]
df["bedrooms_per_room"] = df["total_bedrooms"]/df["total_rooms"]
df["population_per_household"]=df["population"]/df["households"]

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    rooms_per_household  bedrooms_per_room  population_per_household
# ...

# %%
df.corr()["median_house_value"].sort_values(ascending=False)
# Out:
# C:\Users\LimboLEG\AppData\Local\Temp\ipykernel_12268\4243188108.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()["median_house_value"].sort_values(ascending=False)
# median_house_value          1.000000
# median_income               0.688075
# rooms_per_household         0.151948
# total_rooms                 0.134153
# housing_median_age          0.105623
# households                  0.065843
# total_bedrooms              0.050872
# population_per_household   -0.023737
# population                 -0.024650
# longitude                  -0.045967
# latitude                   -0.144160
# bedrooms_per_room          -0.255522
# Name: median_house_value, dtype: float64

# %%
df.hist(bins=50, figsize=(20,15), color='#66c2a5')
plt.show()

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='viridis')
# Out:
# C:\Users\LimboLEG\AppData\Local\Temp\ipykernel_12268\1859166469.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
# <Axes: >

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='median_house_value', y='median_income', data=df, color='#66c2a5')

plt.title('Median House Value vs Median Income', size=20)
plt.xlabel('Median House Value', size=15)
plt.ylabel('Median Income', size=15)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,20))
cax = ax.scatter(df['longitude'], df['latitude'], alpha=0.4,
                 s=df['population']/100, 
                 c=df['median_house_value'], cmap='viridis')
fig.colorbar(cax, label='median house value', orientation='horizontal')
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.show()

# %% [markdown]
# #### Map of California with markers indicating median house values using the Folium library

# %%
import folium

colors = {
    'very_high': '#440154',  
    'high': '#414487',      
    'medium': '#2a788e',    
    'low': '#22a884'        
}

cm = folium.Map(location=[36.7783, -119.4179], zoom_start=6)

for index, row in df.iterrows():
    if row['median_house_value'] > 450000:
        color = colors['very_high']
    elif row['median_house_value'] > 300000:
        color = colors['high']
    elif row['median_house_value'] > 200000:
        color = colors['medium']
    else:
        color = colors['low']
    
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=5,
        color=color,
        fill=True,
        fill_color=color
    ).add_to(cm)
    
cm.save('california_housing_map.html')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")

cmap = sns.color_palette("viridis")

plt.figure(figsize=(12, 8))
sns.countplot(data=df, x='ocean_proximity', palette="viridis")

plt.title('Count of Houses by Ocean Proximity', size=20)
plt.xlabel('Ocean Proximity', size=15)
plt.ylabel('Count', size=15)

plt.show()

# %%
sns.set_style("whitegrid")

cmap = sns.color_palette("viridis", as_cmap=True)

plt.figure(figsize=(12, 8))
sns.boxplot(data=df, x='ocean_proximity', y='median_house_value', palette="viridis")

plt.title('Median House Value by Ocean Proximity', size=20)
plt.xlabel('Ocean Proximity', size=15)
plt.ylabel('Median House Value', size=15)

plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
X = df.drop('median_house_value', axis=1)
y = df['median_house_value']

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
# Listing out the numerical columns for scaling (excluding categorical 'ocean_proximity' and target 'median_house_value')
numerical_cols = df.drop(['ocean_proximity', 'median_house_value'], axis=1).columns

# Setting up a preprocessor that scales numerical columns and one-hot encodes 'ocean_proximity' column
preprocessor = ColumnTransformer(
    transformers = [
        ('num', StandardScaler(), numerical_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), ['ocean_proximity'])
    ])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor

model_rf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(random_state=42))
])

# %%
param_grid = {
    'regressor__n_estimators': [10, 30, 100],
    'regressor__max_features': [2, 4, 6, 8],
    'regressor__bootstrap': [False, True]
}

# Applying GridSearchCV to find the best hyperparameters
grid_search = GridSearchCV(model_rf, param_grid, cv=5, scoring='neg_mean_squared_error', return_train_score=True)
grid_search.fit(X_train, y_train)

print(grid_search.best_params_)
# Out:
# {'regressor__bootstrap': False, 'regressor__max_features': 6, 'regressor__n_estimators': 100}

# %%
#Evaluating the model performance
from sklearn.metrics import mean_squared_error

best_model_rf = grid_search.best_estimator_
y_pred_rf_tuned = best_model_rf.predict(X_test)

print("R^2: {}".format(best_model_rf.score(X_test, y_test)))

rmse_rf_tuned = np.sqrt(mean_squared_error(y_test, y_pred_rf_tuned))
print("Root Mean Squared Error: {}".format(rmse_rf_tuned))
# Out:
# R^2: 0.8264578035626892
# Root Mean Squared Error: 47726.417550669205

# %% [markdown]
# #### R value of around 0.8265 indicates that the model explains about 82.65% of the median house value variable. Furthermore, the Root Mean Squared Error (RMSE) of around 47,726 suggests that on average, the model's predictions deviate by about $47,726 from the actual median house values in the test dataset.

# %%
sample_data = X_test.iloc[:10]

predicted_prices = best_model_rf.predict(sample_data)

actual_prices = y_test.iloc[:10].values

for actual, predicted in zip(actual_prices, predicted_prices):
    print(f"Actual Price: ${actual:.2f} | Predicted Price: ${predicted:.2f}")
# Out:
# Actual Price: $47700.00 | Predicted Price: $46480.00
# Actual Price: $45800.00 | Predicted Price: $69675.00
# Actual Price: $500001.00 | Predicted Price: $488666.71
# Actual Price: $218600.00 | Predicted Price: $255976.00
# Actual Price: $278000.00 | Predicted Price: $244485.00
# Actual Price: $158700.00 | Predicted Price: $160217.00
# Actual Price: $198200.00 | Predicted Price: $222258.00
# Actual Price: $157500.00 | Predicted Price: $164794.00
# Actual Price: $340000.00 | Predicted Price: $254795.03
# Actual Price: $446600.00 | Predicted Price: $448509.47

# %% [markdown]
# ## Conclusion

# %% [markdown]
# #### We began with a detailed exploratory data analysis that revealed the core features influencing house prices, such as median income and proximity to the ocean. We also took a spatial perspective, plotting houses on a map, enabling us to visually identify the correlation between location, house value, and other variables.
#
# #### Our initial handling of missing data was improved through linear regression, giving us a refined dataset to work with. The introduction of derived features such as rooms per household and population per household further enriched our data, providing nuanced insights.
#
# #### The Random Forest model was our machine learning tool of choice, a decision reinforced by its interpretability and effectiveness for regression tasks. Our grid search approach enabled us to fine-tune the model, arriving at an optimized set of parameters that significantly boosted our predictive performance.
